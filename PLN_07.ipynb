# %% [markdown]
# Adaptado por Bruno Menezes (https://github.com/brunoleomenezes) e será utilizado apenas para fins acadêmicos.

# %% [markdown]
# [IMDB PT BR](https://www.kaggle.com/luisfredgs/imdb-ptbr)

# %%
import pandas as pd

textos = pd.read_csv("/content/drive/MyDrive/Curso_PLN/imdb-reviews-pt-br.csv")
textos.head()
# Out:
#    id  ... sentiment
# 0   1  ...       neg
# 1   2  ...       neg
# 2   3  ...       neg
# 3   4  ...       neg
# 4   5  ...       neg
#
# [5 rows x 4 columns]

# %% [markdown]
# Definindo dados de treinamento e teste.

# %%
from sklearn.model_selection import train_test_split

treino, teste, c_treino, c_teste = train_test_split(textos.text_pt, textos.sentiment, random_state = 42)

# %%
teste
# Out:
# 12532    Isso era incomum: um filme moderno que era ult...
# 35445    Alguns dos meus velhos amigos sugeriram que eu...
# 20279    Que prazer. Isto é realmente uma paródia. Some...
# 2969     Há cerca de dez minutos a meio da Strangeland,...
# 45161    Otelo, a clássica história de Shakespearen sob...
#                                ...
# 16421    Crescendo como filho do cinema, uma das trilog...
# 39861    Este filme é o melhor filme de todos os tempos...
# 309      "Electra Glide in Blue" é um movimento lento e...
# 20638    Eu amo esse filme ! Eu acho que já vi 5 vezes ...
# 38935    Eu vi alguns filmes sobre transtornos alimenta...
# Name: text_pt, Length: 12365, dtype: object

# %%
c_teste
# Out:
# 12532    pos
# 35445    neg
# 20279    pos
# 2969     neg
# 45161    pos
#         ...
# 16421    pos
# 39861    pos
# 309      neg
# 20638    pos
# 38935    pos
# Name: sentiment, Length: 12365, dtype: object

# %%
treino
# Out:
# 1348     Embora o filme tenha sido apenas assim, o clos...
# 27466    Este é provavelmente um dos piores filmes que ...
# 29998    De vez em quando, um filme irá varrer ao seu r...
# 48186    Este é um conto completamente diabólico de quã...
# 26473    Lenta, chata, extremamente repetitiva. Não adm...
#                                ...
# 11284    Naach teria ganhado um Razzie para o Pior Film...
# 44732    Apenas assisti a esse filme em DVD e achei a a...
# 38158    Melhor show desde Seinfeld. Ela é realmente mu...
# 860      Eu pareço estar discordando com muitas pessoas...
# 15795    Minhas duas filhas de 11 e 13 anos e eu tive s...
# Name: text_pt, Length: 37094, dtype: object

# %%
c_treino
# Out:
# 1348     neg
# 27466    neg
# 29998    neg
# 48186    pos
# 26473    neg
#         ...
# 11284    neg
# 44732    pos
# 38158    pos
# 860      neg
# 15795    pos
# Name: sentiment, Length: 37094, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

r_log = LogisticRegression()
r_log.fit(treino, c_treino)
ac = r_log.score(teste, c_teste)
print(ac)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-8f7075e78e8a> in <module>()
#       2
#       3 r_log = LogisticRegression()
# ----> 4 r_log.fit(treino, c_treino)
#       5 ac = r_log.score(teste, c_teste)
#       6 print(ac)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
# ...

# %% [markdown]
# Erro! Qual o motivo?

# %% [markdown]
# Primeiro: conhecer aspectos dos textos.

# %%
#Negativa
print(textos.text_pt[189])
#Este é sem dúvida o PIOR filme...
# Out:
# Este é sem dúvida o pior filme que eu já vi. E acredite em mim, eu vi muitos filmes. A reviravolta inacreditável que o filme faz - passando de um extremamente mau filme "Formas de vida alienígenas habitam a terra", com um filme que tenta espalhar um arquicristiano "O dia do julgamento está próximo, buscar Jesus ou queimar por toda a eternidade em as dívidas ardentes do inferno "mensagem - deixou-me atordoado depois de ter sido atormentado por 85 minutos. Até mesmo os cristãos religiosos devem se envergonhar ou ficar furiosos ao ver suas crenças postadas dessa maneira. Eu não sabia o que fazer comigo quando assisti a atuação horrível que poderia ter sido realizada por crianças de 7 anos de idade. Simplesmente repugnante. Eu não sou cristão nem muito religioso. Mas se eu estivesse, não teria mais medo do Inferno. Rich Christiano mostrou ser algo muito pior.

# %%
#Poitivo
print(textos.text_pt[49002])
#...BRILHANTE...
# Out:
# Crescendo em Nova York no final dos anos 80 e início dos anos 90, posso dizer pessoalmente que este é um dos documentários mais importantes feitos para cobrir esse lugar neste período de tempo. Não Madonna não veio com a idéia de Voguing, mas é de onde ela tirou! Em vez de combater a violência uns dos outros ou em brigas de gato, o voguing permitia que as pessoas "lutassem" dentro dos confins de tudo, menos que tocassem umas às outras, o que justificaria uma desqualificação automática. Vendo este tipo de extraordinariamente talentosas / bem orquestradas "jogadas" nos clubes foi nada menos do que espetacular e todos os grandes nomes de antigamente estão aqui ... Pepper La Beija, Paris Duprée, Xtragavaganza, etc. ..tudo comemorado nos gostos de peças de época como a música de Malcom McLarens "Deep in Vogue" ... não importava quem você era, ou de onde você era porque quando você passava por aquelas portas nesse "reino mágico" de De certa forma, você se tornou parte de algo maior que voc
# ...

# %%
print(textos.sentiment.value_counts())
#Está bem balanceado?
classi = textos["sentiment"].replace(["neg", "pos"], [0,1])
textos["classi"] = classi
# Out:
# neg    24765
# pos    24694
# Name: sentiment, dtype: int64

# %%
textos.head()
# Out:
#    id                                            text_en  ... sentiment classi
# 0   1  Once again Mr. Costner has dragged out a movie...  ...       neg      0
# 1   2  This is an example of why the majority of acti...  ...       neg      0
# 2   3  First of all I hate those moronic rappers, who...  ...       neg      0
# 3   4  Not even the Beatles could write songs everyon...  ...       neg      0
# 4   5  Brass pictures movies is not a fitting word fo...  ...       neg      0
#
# [5 rows x 5 columns]

# %% [markdown]
# ![Screenshot 2022-02-10 at 10-37-48 introducao-ao-pln-com-python Aula1 ipynb at master · alura-cursos introducao-ao-pln-com-p[...].png](data:image/png;base64,...)

# %% [markdown]
# #O filme é muito muito bom.

# %% [markdown]
# #O filme é péssimo.

# %% [markdown]
# ![Screenshot 2022-02-10 at 10-41-11 introducao-ao-pln-com-python Aula1 ipynb at master · alura-cursos introducao-ao-pln-com-p[...].png](data:image/png;base64,...)

# %%
from sklearn.feature_extraction.text import CountVectorizer

duas_frases = ["Assisti um filme ótimo", "Assisti um filme ruim"]
vet = CountVectorizer(lowercase=False)
bw= vet.fit_transform(duas_frases)
vet.get_feature_names_out()
# Out:
# array(['Assisti', 'filme', 'ruim', 'um', 'ótimo'], dtype=object)

# %%
matriz = pd.DataFrame.sparse.from_spmatrix(bw, columns=vet.get_feature_names_out())
matriz
# Out:
#    Assisti  filme  ruim  um  ótimo
# 0        1      1     0   1      1
# 1        1      1     1   1      0

# %%
vet = CountVectorizer(lowercase=False)
bw = vet.fit_transform(textos.text_pt)
print(bw.shape) #Dimensões
# Out:
# (49459, 156923)

# %%
vet = CountVectorizer(lowercase=False, max_features=50) #Palavras que mais aparecem no tamanho desejado
bw = vet.fit_transform(textos.text_pt)
print(bw.shape) #Dimensões
# Out:
# (49459, 50)

# %%
from sklearn.model_selection import train_test_split

treino, teste, c_treino, c_teste = train_test_split(bw, textos.sentiment, random_state = 42)

r_log = LogisticRegression()
r_log.fit(treino, c_treino)
ac = r_log.score(teste, c_teste)
print(ac) #Previsão quase 66%
# Out:
# 0.6583097452486858

# %%
def c_t(texto, coluna_texto, coluna_classificacao):
    vet = CountVectorizer(lowercase=False, max_features=50)
    bw = vet.fit_transform(textos.text_pt)
    treino, teste, c_treino, c_teste = train_test_split(bw, textos.sentiment, random_state = 42)

    r_log = LogisticRegression()
    r_log.fit(treino, c_treino)
    return r_log.score(teste, c_teste)
print(c_t(textos, "text_pt", "classificacao"))
# Out:
# 0.6583097452486858

# %%
textos.text_pt
# Out:
# 0        Mais uma vez, o Sr. Costner arrumou um filme p...
# 1        Este é um exemplo do motivo pelo qual a maiori...
# 2        Primeiro de tudo eu odeio esses raps imbecis, ...
# 3        Nem mesmo os Beatles puderam escrever músicas ...
# 4        Filmes de fotos de latão não é uma palavra apr...
#                                ...
# 49454    Como a média de votos era muito baixa, e o fat...
# 49455    O enredo teve algumas reviravoltas infelizes e...
# 49456    Estou espantado com a forma como este filme e ...
# 49457    A Christmas Together realmente veio antes do m...
# 49458    O drama romântico da classe trabalhadora do di...
# Name: text_pt, Length: 49459, dtype: object

# %% [markdown]
# #Como melhorar?

# %%
# %matplotlib inline

from wordcloud import WordCloud
import matplotlib.pyplot as plt

tudo = ' '.join([texto for texto in textos.text_pt])

nuvem = WordCloud(width= 800, height= 500, max_font_size = 110, collocations = False).generate(tudo)
len(tudo)

plt.figure(figsize=(10,7))
plt.imshow(nuvem, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
col_text = textos.text_pt

# %%
def nuvem_neg(textos, col_text):
    negativo = textos.query("sentiment == 'neg'")
    tudo = ' '.join([texto for texto in negativo[col_text]])
    nuvem = WordCloud(width= 800, height= 500, max_font_size = 110, collocations = False).generate(tudo)
    plt.figure(figsize=(10,7))
    plt.imshow(nuvem, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
nuvem_neg(textos, "text_pt")

# %%
def nuvem_pos(textos, col_text):
    positivo = textos.query("sentiment == 'pos'")
    tudo = ' '.join([texto for texto in positivo[col_text]])
    nuvem = WordCloud(width= 800, height= 500, max_font_size = 110, collocations = False).generate(tudo)
    plt.figure(figsize=(10,7))
    plt.imshow(nuvem, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
nuvem_pos(textos, "text_pt")

# %%
import nltk 
mais_duas_frases = ["um filme bom", "um filme ruim"]
freq = nltk.FreqDist(mais_duas_frases)
freq
# Out:
# FreqDist({'um filme bom': 1, 'um filme ruim': 1})

# %%
from nltk import tokenize

apenas_uma_frase = "Processmento de Linguagem Natural, bem vindos!"

tok_espac = tokenize.WhitespaceTokenizer() #por espaço em branco
tok_frase = tok_espac.tokenize(apenas_uma_frase)
tok_frase
# Out:
# ['Processmento', 'de', 'Linguagem', 'Natural,', 'bem', 'vindos!']

# %%
tok_frase = tok_espac.tokenize(tudo)
freq = nltk.FreqDist(tok_frase)
df_freq = pd.DataFrame({"Palavra": list(freq.keys()), "Frequência": list(freq.values())})
df_freq.nlargest(columns = "Frequência", n = 10)
# Out:
#     Palavra  Frequência
# 20       de      417651
# 14      que      325070
# 42        e      299743
# 3         o      244881
# 7        um      216410
# 102       a      210179
# 45        é      192381
# 200      em      132778
# 1       uma      130888
# 29      não      127915

# %%
import seaborn as sns
    
def paret(textos, col_text, quant):
    tudo = ' '.join([texto for texto in textos.text_pt])
    tok_frase = tok_espac.tokenize(tudo)
    freq = nltk.FreqDist(tok_frase)
    df_freq = pd.DataFrame({"Palavra": list(freq.keys()), "Frequência": list(freq.values())})
    df_freq = df_freq.nlargest(columns = "Frequência", n = quant)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_freq, x = "Palavra", y = "Frequência", color = 'gray')
    ax.set(ylabel = "Contagem")
    plt.show()



paret(textos, "text_pt", 10)

# %%
import nltk
nltk.download('stopwords')

irrel = nltk.corpus.stopwords.words("portuguese")

f_proc = list()
for op in textos.text_pt:
    nova_f = list()
    p_texto = tok_espac.tokenize(op)
    for palavra in p_texto:
        if palavra not in irrel:
            nova_f.append(palavra)
    f_proc.append(' '.join(nova_f))
    
textos["t01"] = f_proc
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
textos.head()
# Out:
#    id  ...                                                t01
# 0   1  ...  Mais vez, Sr. Costner arrumou filme tempo nece...
# 1   2  ...  Este exemplo motivo maioria filmes ação mesmos...
# 2   3  ...  Primeiro tudo odeio raps imbecis, poderiam agi...
# 3   4  ...  Nem Beatles puderam escrever músicas todos gos...
# 4   5  ...  Filmes fotos latão palavra apropriada eles, ve...
#
# [5 rows x 6 columns]

# %%
c_t(textos, "t01", "classificacao")
# Out:
# 0.6583097452486858

# %%
paret(textos,"t01", 20)
