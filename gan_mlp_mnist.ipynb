# %% [markdown]
# Adaptado por Bruno Menezes (https://github.com/brunoleomenezes) de Sebastian Raschka e será utilizado apenas para fins acadêmicos.

# %% [markdown]
# # Generative Adversarial Networks (GAN)

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import DataLoader


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Hyperparameters
random_seed = 123
generator_learning_rate = 0.001
discriminator_learning_rate = 0.001
num_epochs = 100
batch_size = 128
LATENT_DIM = 100
IMG_SHAPE = (1, 28, 28)
IMG_SIZE = 1
for x in IMG_SHAPE:
    IMG_SIZE *= x



##########################
### MNIST DATASET
##########################

# Note transforms.ToTensor() scales input images
# to 0-1 range
train_dataset = datasets.MNIST(root='data', 
                               train=True, 
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='data', 
                              train=False, 
                              transform=transforms.ToTensor())


train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=batch_size, 
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=batch_size, 
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()
        
        
        self.generator = nn.Sequential(
            nn.Linear(LATENT_DIM, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, IMG_SIZE),
            nn.Tanh()
        )
        
        self.discriminator = nn.Sequential(
            nn.Linear(IMG_SIZE, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

            
    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        pred = model.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

model = GAN()
model = model.to(device)

optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)

# %% [markdown]
# ## Training

# %%
start_time = time.time()    

discr_costs = []
gener_costs = []
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):

        
        
        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device) 
        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)
        

        ### FORWARD AND BACK PROP
        
        
        # --------------------------
        # Train Generator
        # --------------------------
        
        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)
        
        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features)
        
        gener_loss = F.binary_cross_entropy(discr_pred, valid)
        
        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()
        
        # --------------------------
        # Train Discriminator
        # --------------------------        
        
        discr_pred_real = model.discriminator_forward(features.view(-1, IMG_SIZE))
        real_loss = F.binary_cross_entropy(discr_pred_real, valid)
        
        discr_pred_fake = model.discriminator_forward(generated_features.detach())
        fake_loss = F.binary_cross_entropy(discr_pred_fake, fake)
        
        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()        
        
        discr_costs.append(discr_loss.item())
        gener_costs.append(gener_loss.item())
        
        
        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/100 | Batch 000/469 | Gen/Dis Loss: 0.6863/0.7142
# Epoch: 001/100 | Batch 100/469 | Gen/Dis Loss: 4.1770/0.0483
# Epoch: 001/100 | Batch 200/469 | Gen/Dis Loss: 1.8416/0.1063
# Epoch: 001/100 | Batch 300/469 | Gen/Dis Loss: 1.1759/0.2703
# Epoch: 001/100 | Batch 400/469 | Gen/Dis Loss: 1.0711/0.3258
# Time elapsed: 0.35 min
# Epoch: 002/100 | Batch 000/469 | Gen/Dis Loss: 2.6364/0.0903
# Epoch: 002/100 | Batch 100/469 | Gen/Dis Loss: 1.2044/0.2729
# Epoch: 002/100 | Batch 200/469 | Gen/Dis Loss: 0.9527/0.4740
# Epoch: 002/100 | Batch 300/469 | Gen/Dis Loss: 0.6786/0.6168
# Epoch: 002/100 | Batch 400/469 | Gen/Dis Loss: 0.9757/0.4233
# Time elapsed: 0.57 min
# Epoch: 003/100 | Batch 000/469 | Gen/Dis Loss: 0.8195/0.5274
# Epoch: 003/100 | Batch 100/469 | Gen/Dis Loss: 0.7891/0.4997
# Epoch: 003/100 | Batch 200/469 | Gen/Dis Loss: 1.0676/0.4039
# Epoch: 003/100 | Batch 300/469 | Gen/Dis Loss: 1.8515/0.3826
# Epoch: 003/100 | Batch 400/469 | Gen/Dis Loss: 1.0819/0.3234
# Time elapsed: 0.82 min
# Epoch: 004/100 | Batch 000/469 | Gen/Dis Loss: 1.5073/0.4527
# Epoch: 004/100 | Batch 100/469 | Gen/Dis Loss: 1.5987/0.3550
# Epoch: 004/100 | Batch 200/469 | Gen/Dis Loss: 2.2226/0.3351
# Epoch: 004/100 | Batch 300/469 | Gen/Dis Loss: 1.4156/0.3343
# Epoch: 004/100 | Batch 400/469 | Gen/Dis Loss: 1.4819/0.4159
# Time elapsed: 1.04 min
# Epoch: 005/100 | Batch 000/469 | Gen/Dis Loss: 1.1741/0.4251
# Epoch: 005/100 | Batch 100/469 | Gen/Dis Loss: 1.1171/0.5120
# Epoch: 005/100 | Batch 200/469 | Gen/Dis Loss: 0.8579/0.5935
# Epoch: 005/100 | Batch 300/469 | Gen/Dis Loss: 0.8353/0.5577
# Epoch: 005/100 | Batch 400/469 | Gen/Dis Loss: 0.7321/0.5785
# Time elapsed: 1.26 min
# Epoch: 006/100 | Batch 000/469 | Gen/Dis Loss: 1.0096/0.5140
# Epoch: 006/100 | Batch 100/469 | Gen/Dis Loss: 0.8629/0.5513
# Epoch: 006/100 | Batch 200/469 | Gen/Dis Loss: 1.0155/0.5861
# Epoch: 006/100 | Batch 300/469 | Gen/Dis Loss: 0.9669/0.5288
# Epoch: 006/100 | Batch 400/469 | Gen/Dis Loss: 0.9648/0.5520
# Time elapsed: 1.49 min
# Epoch: 007/100 | Batch 000/469 | Gen/Dis Loss: 0.7800/0.5518
# Epoch: 007/100 | Batch 100/469 | Gen/Dis Loss: 0.7973/0.5874
# Epoch: 007/100 | Batch 200/469 | Gen/Dis Loss: 1.6519/0.5349
# Epoch: 007/100 | Batch 300/469 | Gen/Dis Loss: 0.9345/0.4851
# Epoch: 007/100 | Batch 400/469 | Gen/Dis Loss: 0.6957/0.5712
# Time elapsed: 1.71 min
# Epoch: 008/100 | Batch 000/469 | Gen/Dis Loss: 1.4178/0.4884
# Epoch: 008/100 | Batch 100/469 | Gen/Dis Loss: 1.3630/0.4658
# Epoch: 008/100 | Batch 200/469 | Gen/Dis Loss: 1.3488/0.4956
# Epoch: 008/100 | Batch 300/469 | Gen/Dis Loss: 1.3222/0.4430
# Epoch: 008/100 | Batch 400/469 | Gen/Dis Loss: 1.6658/0.4279
# Time elapsed: 1.95 min
# Epoch: 009/100 | Batch 000/469 | Gen/Dis Loss: 1.2281/0.4896
# Epoch: 009/100 | Batch 100/469 | Gen/Dis Loss: 1.0868/0.5294
# Epoch: 009/100 | Batch 200/469 | Gen/Dis Loss: 1.0918/0.5720
# Epoch: 009/100 | Batch 300/469 | Gen/Dis Loss: 1.1327/0.4368
# Epoch: 009/100 | Batch 400/469 | Gen/Dis Loss: 1.3096/0.4748
# Time elapsed: 2.17 min
# Epoch: 010/100 | Batch 000/469 | Gen/Dis Loss: 0.9637/0.6263
# Epoch: 010/100 | Batch 100/469 | Gen/Dis Loss: 2.0731/0.5487
# Epoch: 010/100 | Batch 200/469 | Gen/Dis Loss: 0.9906/0.5713
# Epoch: 010/100 | Batch 300/469 | Gen/Dis Loss: 0.9875/0.5365
# Epoch: 010/100 | Batch 400/469 | Gen/Dis Loss: 1.2010/0.4524
# Time elapsed: 2.41 min
# Epoch: 011/100 | Batch 000/469 | Gen/Dis Loss: 0.9725/0.5143
# Epoch: 011/100 | Batch 100/469 | Gen/Dis Loss: 1.4420/0.3365
# Epoch: 011/100 | Batch 200/469 | Gen/Dis Loss: 1.1559/0.4510
# Epoch: 011/100 | Batch 300/469 | Gen/Dis Loss: 1.4713/0.4927
# Epoch: 011/100 | Batch 400/469 | Gen/Dis Loss: 0.9187/0.5239
# Time elapsed: 2.63 min
# Epoch: 012/100 | Batch 000/469 | Gen/Dis Loss: 1.2559/0.4967
# Epoch: 012/100 | Batch 100/469 | Gen/Dis Loss: 1.0558/0.4930
# Epoch: 012/100 | Batch 200/469 | Gen/Dis Loss: 1.0506/0.5031
# Epoch: 012/100 | Batch 300/469 | Gen/Dis Loss: 1.1867/0.5216
# Epoch: 012/100 | Batch 400/469 | Gen/Dis Loss: 1.1686/0.5751
# Time elapsed: 2.85 min
# Epoch: 013/100 | Batch 000/469 | Gen/Dis Loss: 1.0683/0.5631
# Epoch: 013/100 | Batch 100/469 | Gen/Dis Loss: 1.0118/0.5749
# Epoch: 013/100 | Batch 200/469 | Gen/Dis Loss: 0.8945/0.5744
# Epoch: 013/100 | Batch 300/469 | Gen/Dis Loss: 1.1569/0.5593
# Epoch: 013/100 | Batch 400/469 | Gen/Dis Loss: 1.2141/0.4660
# Time elapsed: 3.08 min
# Epoch: 014/100 | Batch 000/469 | Gen/Dis Loss: 1.4570/0.4786
# Epoch: 014/100 | Batch 100/469 | Gen/Dis Loss: 1.1239/0.5086
# Epoch: 014/100 | Batch 200/469 | Gen/Dis Loss: 1.3406/0.6005
# Epoch: 014/100 | Batch 300/469 | Gen/Dis Loss: 1.1805/0.4972
# Epoch: 014/100 | Batch 400/469 | Gen/Dis Loss: 1.3474/0.5064
# Time elapsed: 3.30 min
# Epoch: 015/100 | Batch 000/469 | Gen/Dis Loss: 1.0629/0.5133
# Epoch: 015/100 | Batch 100/469 | Gen/Dis Loss: 0.8927/0.6058
# Epoch: 015/100 | Batch 200/469 | Gen/Dis Loss: 0.8992/0.5513
# Epoch: 015/100 | Batch 300/469 | Gen/Dis Loss: 1.2247/0.6012
# Epoch: 015/100 | Batch 400/469 | Gen/Dis Loss: 1.3431/0.4295
# Time elapsed: 3.52 min
# Epoch: 016/100 | Batch 000/469 | Gen/Dis Loss: 1.5321/0.4854
# Epoch: 016/100 | Batch 100/469 | Gen/Dis Loss: 0.9412/0.5803
# Epoch: 016/100 | Batch 200/469 | Gen/Dis Loss: 1.5021/0.5294
# Epoch: 016/100 | Batch 300/469 | Gen/Dis Loss: 1.0756/0.5224
# Epoch: 016/100 | Batch 400/469 | Gen/Dis Loss: 1.1389/0.4931
# Time elapsed: 3.74 min
# Epoch: 017/100 | Batch 000/469 | Gen/Dis Loss: 1.1994/0.5083
# Epoch: 017/100 | Batch 100/469 | Gen/Dis Loss: 1.0724/0.5257
# Epoch: 017/100 | Batch 200/469 | Gen/Dis Loss: 1.0497/0.5070
# Epoch: 017/100 | Batch 300/469 | Gen/Dis Loss: 1.1562/0.4930
# Epoch: 017/100 | Batch 400/469 | Gen/Dis Loss: 0.8899/0.5334
# Time elapsed: 3.97 min
# Epoch: 018/100 | Batch 000/469 | Gen/Dis Loss: 1.0536/0.4853
# Epoch: 018/100 | Batch 100/469 | Gen/Dis Loss: 1.3905/0.5605
# Epoch: 018/100 | Batch 200/469 | Gen/Dis Loss: 0.9577/0.5468
# Epoch: 018/100 | Batch 300/469 | Gen/Dis Loss: 1.2202/0.4981
# Epoch: 018/100 | Batch 400/469 | Gen/Dis Loss: 1.2150/0.5194
# Time elapsed: 4.21 min
# Epoch: 019/100 | Batch 000/469 | Gen/Dis Loss: 1.1785/0.5698
# Epoch: 019/100 | Batch 100/469 | Gen/Dis Loss: 1.1357/0.5361
# Epoch: 019/100 | Batch 200/469 | Gen/Dis Loss: 1.4313/0.5478
# Epoch: 019/100 | Batch 300/469 | Gen/Dis Loss: 1.2740/0.5546
# Epoch: 019/100 | Batch 400/469 | Gen/Dis Loss: 1.1700/0.5905
# Time elapsed: 4.43 min
# Epoch: 020/100 | Batch 000/469 | Gen/Dis Loss: 1.2347/0.5393
# Epoch: 020/100 | Batch 100/469 | Gen/Dis Loss: 1.2322/0.4883
# Epoch: 020/100 | Batch 200/469 | Gen/Dis Loss: 1.2774/0.5424
# Epoch: 020/100 | Batch 300/469 | Gen/Dis Loss: 0.9788/0.5447
# Epoch: 020/100 | Batch 400/469 | Gen/Dis Loss: 1.2799/0.5150
# Time elapsed: 4.65 min
# Epoch: 021/100 | Batch 000/469 | Gen/Dis Loss: 1.3362/0.4982
# Epoch: 021/100 | Batch 100/469 | Gen/Dis Loss: 1.5104/0.5207
# Epoch: 021/100 | Batch 200/469 | Gen/Dis Loss: 1.0871/0.5224
# Epoch: 021/100 | Batch 300/469 | Gen/Dis Loss: 1.0667/0.5970
# Epoch: 021/100 | Batch 400/469 | Gen/Dis Loss: 0.8889/0.5688
# Time elapsed: 4.88 min
# Epoch: 022/100 | Batch 000/469 | Gen/Dis Loss: 1.3350/0.5281
# Epoch: 022/100 | Batch 100/469 | Gen/Dis Loss: 1.2377/0.5481
# Epoch: 022/100 | Batch 200/469 | Gen/Dis Loss: 0.9715/0.5264
# Epoch: 022/100 | Batch 300/469 | Gen/Dis Loss: 1.1505/0.5808
# Epoch: 022/100 | Batch 400/469 | Gen/Dis Loss: 0.9754/0.5449
# Time elapsed: 5.10 min
# Epoch: 023/100 | Batch 000/469 | Gen/Dis Loss: 0.9053/0.5839
# Epoch: 023/100 | Batch 100/469 | Gen/Dis Loss: 0.9759/0.5244
# Epoch: 023/100 | Batch 200/469 | Gen/Dis Loss: 1.4108/0.4948
# Epoch: 023/100 | Batch 300/469 | Gen/Dis Loss: 1.3105/0.5687
# Epoch: 023/100 | Batch 400/469 | Gen/Dis Loss: 1.5382/0.4927
# Time elapsed: 5.32 min
# Epoch: 024/100 | Batch 000/469 | Gen/Dis Loss: 1.0142/0.4872
# Epoch: 024/100 | Batch 100/469 | Gen/Dis Loss: 0.9159/0.5877
# Epoch: 024/100 | Batch 200/469 | Gen/Dis Loss: 1.0780/0.5190
# Epoch: 024/100 | Batch 300/469 | Gen/Dis Loss: 1.1759/0.5802
# Epoch: 024/100 | Batch 400/469 | Gen/Dis Loss: 1.0023/0.5358
# Time elapsed: 5.55 min
# Epoch: 025/100 | Batch 000/469 | Gen/Dis Loss: 1.2805/0.5452
# Epoch: 025/100 | Batch 100/469 | Gen/Dis Loss: 1.1613/0.5748
# Epoch: 025/100 | Batch 200/469 | Gen/Dis Loss: 1.6085/0.5947
# Epoch: 025/100 | Batch 300/469 | Gen/Dis Loss: 1.2316/0.4811
# Epoch: 025/100 | Batch 400/469 | Gen/Dis Loss: 1.0477/0.5962
# Time elapsed: 5.77 min
# Epoch: 026/100 | Batch 000/469 | Gen/Dis Loss: 1.0010/0.5221
# Epoch: 026/100 | Batch 100/469 | Gen/Dis Loss: 0.9499/0.5324
# Epoch: 026/100 | Batch 200/469 | Gen/Dis Loss: 0.8857/0.5719
# Epoch: 026/100 | Batch 300/469 | Gen/Dis Loss: 0.9996/0.5452
# Epoch: 026/100 | Batch 400/469 | Gen/Dis Loss: 0.9536/0.5799
# Time elapsed: 6.00 min
# Epoch: 027/100 | Batch 000/469 | Gen/Dis Loss: 1.6984/0.5256
# Epoch: 027/100 | Batch 100/469 | Gen/Dis Loss: 1.4223/0.4996
# Epoch: 027/100 | Batch 200/469 | Gen/Dis Loss: 1.2654/0.5756
# Epoch: 027/100 | Batch 300/469 | Gen/Dis Loss: 1.0441/0.5137
# Epoch: 027/100 | Batch 400/469 | Gen/Dis Loss: 1.4440/0.5945
# Time elapsed: 6.24 min
# Epoch: 028/100 | Batch 000/469 | Gen/Dis Loss: 1.3128/0.5395
# Epoch: 028/100 | Batch 100/469 | Gen/Dis Loss: 0.8528/0.6115
# Epoch: 028/100 | Batch 200/469 | Gen/Dis Loss: 1.1352/0.5579
# Epoch: 028/100 | Batch 300/469 | Gen/Dis Loss: 0.9294/0.6043
# Epoch: 028/100 | Batch 400/469 | Gen/Dis Loss: 0.9679/0.6150
# Time elapsed: 6.47 min
# Epoch: 029/100 | Batch 000/469 | Gen/Dis Loss: 1.1088/0.5870
# Epoch: 029/100 | Batch 100/469 | Gen/Dis Loss: 0.9321/0.5519
# Epoch: 029/100 | Batch 200/469 | Gen/Dis Loss: 1.3115/0.6011
# Epoch: 029/100 | Batch 300/469 | Gen/Dis Loss: 1.1165/0.5502
# Epoch: 029/100 | Batch 400/469 | Gen/Dis Loss: 1.3027/0.5189
# Time elapsed: 6.69 min
# Epoch: 030/100 | Batch 000/469 | Gen/Dis Loss: 0.9591/0.5497
# Epoch: 030/100 | Batch 100/469 | Gen/Dis Loss: 1.3047/0.5770
# Epoch: 030/100 | Batch 200/469 | Gen/Dis Loss: 1.0964/0.5948
# Epoch: 030/100 | Batch 300/469 | Gen/Dis Loss: 0.9881/0.5727
# Epoch: 030/100 | Batch 400/469 | Gen/Dis Loss: 1.0767/0.5204
# Time elapsed: 6.92 min
# Epoch: 031/100 | Batch 000/469 | Gen/Dis Loss: 0.8845/0.6089
# Epoch: 031/100 | Batch 100/469 | Gen/Dis Loss: 0.8670/0.5972
# Epoch: 031/100 | Batch 200/469 | Gen/Dis Loss: 0.9486/0.5770
# Epoch: 031/100 | Batch 300/469 | Gen/Dis Loss: 0.8986/0.5755
# Epoch: 031/100 | Batch 400/469 | Gen/Dis Loss: 0.9417/0.6224
# Time elapsed: 7.14 min
# Epoch: 032/100 | Batch 000/469 | Gen/Dis Loss: 0.9459/0.5791
# Epoch: 032/100 | Batch 100/469 | Gen/Dis Loss: 1.0803/0.6107
# Epoch: 032/100 | Batch 200/469 | Gen/Dis Loss: 0.9686/0.5428
# Epoch: 032/100 | Batch 300/469 | Gen/Dis Loss: 1.1236/0.5763
# Epoch: 032/100 | Batch 400/469 | Gen/Dis Loss: 1.3341/0.6119
# Time elapsed: 7.37 min
# Epoch: 033/100 | Batch 000/469 | Gen/Dis Loss: 1.5027/0.5371
# Epoch: 033/100 | Batch 100/469 | Gen/Dis Loss: 1.0403/0.5878
# Epoch: 033/100 | Batch 200/469 | Gen/Dis Loss: 0.8732/0.6363
# Epoch: 033/100 | Batch 300/469 | Gen/Dis Loss: 0.8739/0.5823
# Epoch: 033/100 | Batch 400/469 | Gen/Dis Loss: 0.8174/0.6000
# Time elapsed: 7.60 min
# Epoch: 034/100 | Batch 000/469 | Gen/Dis Loss: 1.1143/0.6136
# Epoch: 034/100 | Batch 100/469 | Gen/Dis Loss: 0.9386/0.5802
# Epoch: 034/100 | Batch 200/469 | Gen/Dis Loss: 1.0676/0.6169
# Epoch: 034/100 | Batch 300/469 | Gen/Dis Loss: 1.1673/0.5293
# Epoch: 034/100 | Batch 400/469 | Gen/Dis Loss: 1.0164/0.5992
# Time elapsed: 7.82 min
# Epoch: 035/100 | Batch 000/469 | Gen/Dis Loss: 0.9178/0.5664
# Epoch: 035/100 | Batch 100/469 | Gen/Dis Loss: 1.1476/0.5210
# Epoch: 035/100 | Batch 200/469 | Gen/Dis Loss: 0.7583/0.6243
# Epoch: 035/100 | Batch 300/469 | Gen/Dis Loss: 0.9211/0.6593
# Epoch: 035/100 | Batch 400/469 | Gen/Dis Loss: 0.9483/0.5804
# Time elapsed: 8.04 min
# Epoch: 036/100 | Batch 000/469 | Gen/Dis Loss: 1.1797/0.5588
# Epoch: 036/100 | Batch 100/469 | Gen/Dis Loss: 0.9224/0.5971
# Epoch: 036/100 | Batch 200/469 | Gen/Dis Loss: 0.7987/0.6268
# Epoch: 036/100 | Batch 300/469 | Gen/Dis Loss: 1.0813/0.6005
# Epoch: 036/100 | Batch 400/469 | Gen/Dis Loss: 1.1861/0.5511
# Time elapsed: 8.26 min
# Epoch: 037/100 | Batch 000/469 | Gen/Dis Loss: 0.9419/0.6486
# Epoch: 037/100 | Batch 100/469 | Gen/Dis Loss: 1.0192/0.5664
# Epoch: 037/100 | Batch 200/469 | Gen/Dis Loss: 0.8895/0.5684
# Epoch: 037/100 | Batch 300/469 | Gen/Dis Loss: 0.7290/0.6010
# Epoch: 037/100 | Batch 400/469 | Gen/Dis Loss: 0.9344/0.6264
# Time elapsed: 8.49 min
# Epoch: 038/100 | Batch 000/469 | Gen/Dis Loss: 0.8754/0.5897
# Epoch: 038/100 | Batch 100/469 | Gen/Dis Loss: 1.2623/0.5719
# Epoch: 038/100 | Batch 200/469 | Gen/Dis Loss: 0.9200/0.6278
# Epoch: 038/100 | Batch 300/469 | Gen/Dis Loss: 0.9322/0.6204
# Epoch: 038/100 | Batch 400/469 | Gen/Dis Loss: 0.8779/0.6177
# Time elapsed: 8.72 min
# Epoch: 039/100 | Batch 000/469 | Gen/Dis Loss: 0.8217/0.5890
# Epoch: 039/100 | Batch 100/469 | Gen/Dis Loss: 0.8893/0.6054
# Epoch: 039/100 | Batch 200/469 | Gen/Dis Loss: 0.8609/0.6148
# Epoch: 039/100 | Batch 300/469 | Gen/Dis Loss: 0.8665/0.6075
# Epoch: 039/100 | Batch 400/469 | Gen/Dis Loss: 0.8577/0.6162
# Time elapsed: 8.94 min
# Epoch: 040/100 | Batch 000/469 | Gen/Dis Loss: 1.2997/0.6393
# Epoch: 040/100 | Batch 100/469 | Gen/Dis Loss: 0.8311/0.5981
# Epoch: 040/100 | Batch 200/469 | Gen/Dis Loss: 0.9118/0.6093
# Epoch: 040/100 | Batch 300/469 | Gen/Dis Loss: 1.0570/0.6329
# Epoch: 040/100 | Batch 400/469 | Gen/Dis Loss: 0.8610/0.6453
# Time elapsed: 9.16 min
# Epoch: 041/100 | Batch 000/469 | Gen/Dis Loss: 0.9498/0.6173
# Epoch: 041/100 | Batch 100/469 | Gen/Dis Loss: 0.8706/0.6189
# Epoch: 041/100 | Batch 200/469 | Gen/Dis Loss: 0.8628/0.6055
# Epoch: 041/100 | Batch 300/469 | Gen/Dis Loss: 0.9371/0.6109
# Epoch: 041/100 | Batch 400/469 | Gen/Dis Loss: 0.8466/0.6257
# Time elapsed: 9.38 min
# Epoch: 042/100 | Batch 000/469 | Gen/Dis Loss: 0.9403/0.6431
# Epoch: 042/100 | Batch 100/469 | Gen/Dis Loss: 0.8749/0.6189
# Epoch: 042/100 | Batch 200/469 | Gen/Dis Loss: 1.0916/0.5626
# Epoch: 042/100 | Batch 300/469 | Gen/Dis Loss: 1.3989/0.5611
# Epoch: 042/100 | Batch 400/469 | Gen/Dis Loss: 1.0510/0.6035
# Time elapsed: 9.61 min
# Epoch: 043/100 | Batch 000/469 | Gen/Dis Loss: 1.0337/0.6366
# Epoch: 043/100 | Batch 100/469 | Gen/Dis Loss: 0.8778/0.6118
# Epoch: 043/100 | Batch 200/469 | Gen/Dis Loss: 0.8630/0.6454
# Epoch: 043/100 | Batch 300/469 | Gen/Dis Loss: 0.8774/0.5914
# Epoch: 043/100 | Batch 400/469 | Gen/Dis Loss: 0.8481/0.6244
# Time elapsed: 9.83 min
# Epoch: 044/100 | Batch 000/469 | Gen/Dis Loss: 0.7736/0.6606
# Epoch: 044/100 | Batch 100/469 | Gen/Dis Loss: 0.9434/0.5810
# Epoch: 044/100 | Batch 200/469 | Gen/Dis Loss: 0.9947/0.6038
# Epoch: 044/100 | Batch 300/469 | Gen/Dis Loss: 0.9387/0.5837
# Epoch: 044/100 | Batch 400/469 | Gen/Dis Loss: 0.8788/0.6177
# Time elapsed: 10.05 min
# Epoch: 045/100 | Batch 000/469 | Gen/Dis Loss: 1.1385/0.5720
# Epoch: 045/100 | Batch 100/469 | Gen/Dis Loss: 0.9682/0.6373
# Epoch: 045/100 | Batch 200/469 | Gen/Dis Loss: 0.8642/0.6508
# Epoch: 045/100 | Batch 300/469 | Gen/Dis Loss: 0.7539/0.6415
# Epoch: 045/100 | Batch 400/469 | Gen/Dis Loss: 1.1280/0.6274
# Time elapsed: 10.27 min
# Epoch: 046/100 | Batch 000/469 | Gen/Dis Loss: 0.7942/0.6297
# Epoch: 046/100 | Batch 100/469 | Gen/Dis Loss: 0.9285/0.6486
# Epoch: 046/100 | Batch 200/469 | Gen/Dis Loss: 0.8823/0.5852
# Epoch: 046/100 | Batch 300/469 | Gen/Dis Loss: 1.0284/0.5872
# Epoch: 046/100 | Batch 400/469 | Gen/Dis Loss: 0.9686/0.6335
# Time elapsed: 10.50 min
# Epoch: 047/100 | Batch 000/469 | Gen/Dis Loss: 0.8618/0.5656
# Epoch: 047/100 | Batch 100/469 | Gen/Dis Loss: 0.8602/0.6148
# Epoch: 047/100 | Batch 200/469 | Gen/Dis Loss: 1.0838/0.5947
# Epoch: 047/100 | Batch 300/469 | Gen/Dis Loss: 1.2279/0.5814
# Epoch: 047/100 | Batch 400/469 | Gen/Dis Loss: 0.8748/0.6567
# Time elapsed: 10.72 min
# Epoch: 048/100 | Batch 000/469 | Gen/Dis Loss: 0.8654/0.6135
# Epoch: 048/100 | Batch 100/469 | Gen/Dis Loss: 0.8818/0.6283
# Epoch: 048/100 | Batch 200/469 | Gen/Dis Loss: 0.9027/0.6475
# Epoch: 048/100 | Batch 300/469 | Gen/Dis Loss: 0.9629/0.6244
# Epoch: 048/100 | Batch 400/469 | Gen/Dis Loss: 0.9174/0.6027
# Time elapsed: 10.94 min
# Epoch: 049/100 | Batch 000/469 | Gen/Dis Loss: 1.1151/0.6105
# Epoch: 049/100 | Batch 100/469 | Gen/Dis Loss: 1.0060/0.6089
# Epoch: 049/100 | Batch 200/469 | Gen/Dis Loss: 0.7238/0.6551
# Epoch: 049/100 | Batch 300/469 | Gen/Dis Loss: 0.9448/0.6001
# Epoch: 049/100 | Batch 400/469 | Gen/Dis Loss: 0.9095/0.5758
# Time elapsed: 11.16 min
# Epoch: 050/100 | Batch 000/469 | Gen/Dis Loss: 0.7833/0.6207
# Epoch: 050/100 | Batch 100/469 | Gen/Dis Loss: 0.8022/0.6207
# Epoch: 050/100 | Batch 200/469 | Gen/Dis Loss: 0.8133/0.6244
# Epoch: 050/100 | Batch 300/469 | Gen/Dis Loss: 0.9004/0.6282
# Epoch: 050/100 | Batch 400/469 | Gen/Dis Loss: 0.8223/0.6621
# Time elapsed: 11.38 min
# Epoch: 051/100 | Batch 000/469 | Gen/Dis Loss: 0.8710/0.6092
# Epoch: 051/100 | Batch 100/469 | Gen/Dis Loss: 1.0127/0.6017
# Epoch: 051/100 | Batch 200/469 | Gen/Dis Loss: 0.9854/0.6017
# Epoch: 051/100 | Batch 300/469 | Gen/Dis Loss: 0.9726/0.6515
# Epoch: 051/100 | Batch 400/469 | Gen/Dis Loss: 0.8541/0.6718
# Time elapsed: 11.60 min
# Epoch: 052/100 | Batch 000/469 | Gen/Dis Loss: 0.9956/0.6311
# Epoch: 052/100 | Batch 100/469 | Gen/Dis Loss: 0.9629/0.5986
# Epoch: 052/100 | Batch 200/469 | Gen/Dis Loss: 0.9303/0.6611
# Epoch: 052/100 | Batch 300/469 | Gen/Dis Loss: 0.8970/0.5922
# Epoch: 052/100 | Batch 400/469 | Gen/Dis Loss: 0.8519/0.6420
# Time elapsed: 11.82 min
# Epoch: 053/100 | Batch 000/469 | Gen/Dis Loss: 0.8865/0.6237
# Epoch: 053/100 | Batch 100/469 | Gen/Dis Loss: 0.8597/0.6740
# Epoch: 053/100 | Batch 200/469 | Gen/Dis Loss: 0.8481/0.6108
# Epoch: 053/100 | Batch 300/469 | Gen/Dis Loss: 0.8553/0.6263
# Epoch: 053/100 | Batch 400/469 | Gen/Dis Loss: 1.0552/0.5544
# Time elapsed: 12.04 min
# Epoch: 054/100 | Batch 000/469 | Gen/Dis Loss: 0.8507/0.6656
# Epoch: 054/100 | Batch 100/469 | Gen/Dis Loss: 0.8101/0.6211
# Epoch: 054/100 | Batch 200/469 | Gen/Dis Loss: 0.7360/0.6573
# Epoch: 054/100 | Batch 300/469 | Gen/Dis Loss: 0.8390/0.6376
# Epoch: 054/100 | Batch 400/469 | Gen/Dis Loss: 0.8871/0.6213
# Time elapsed: 12.26 min
# Epoch: 055/100 | Batch 000/469 | Gen/Dis Loss: 1.1388/0.6167
# Epoch: 055/100 | Batch 100/469 | Gen/Dis Loss: 0.7782/0.6395
# Epoch: 055/100 | Batch 200/469 | Gen/Dis Loss: 0.8193/0.5916
# Epoch: 055/100 | Batch 300/469 | Gen/Dis Loss: 0.8807/0.6366
# Epoch: 055/100 | Batch 400/469 | Gen/Dis Loss: 0.8870/0.6144
# Time elapsed: 12.48 min
# Epoch: 056/100 | Batch 000/469 | Gen/Dis Loss: 0.8167/0.5912
# Epoch: 056/100 | Batch 100/469 | Gen/Dis Loss: 0.8839/0.6212
# Epoch: 056/100 | Batch 200/469 | Gen/Dis Loss: 0.7818/0.6184
# Epoch: 056/100 | Batch 300/469 | Gen/Dis Loss: 0.8591/0.6366
# Epoch: 056/100 | Batch 400/469 | Gen/Dis Loss: 0.8478/0.6404
# Time elapsed: 12.71 min
# Epoch: 057/100 | Batch 000/469 | Gen/Dis Loss: 0.7641/0.6591
# Epoch: 057/100 | Batch 100/469 | Gen/Dis Loss: 1.1700/0.6406
# Epoch: 057/100 | Batch 200/469 | Gen/Dis Loss: 1.0883/0.5904
# Epoch: 057/100 | Batch 300/469 | Gen/Dis Loss: 0.9888/0.5874
# Epoch: 057/100 | Batch 400/469 | Gen/Dis Loss: 0.9704/0.6132
# Time elapsed: 12.94 min
# Epoch: 058/100 | Batch 000/469 | Gen/Dis Loss: 0.8195/0.6223
# Epoch: 058/100 | Batch 100/469 | Gen/Dis Loss: 0.7970/0.6605
# Epoch: 058/100 | Batch 200/469 | Gen/Dis Loss: 0.8735/0.6378
# Epoch: 058/100 | Batch 300/469 | Gen/Dis Loss: 0.9137/0.5896
# Epoch: 058/100 | Batch 400/469 | Gen/Dis Loss: 0.7622/0.6340
# Time elapsed: 13.16 min
# Epoch: 059/100 | Batch 000/469 | Gen/Dis Loss: 0.8523/0.6097
# Epoch: 059/100 | Batch 100/469 | Gen/Dis Loss: 0.8847/0.6199
# Epoch: 059/100 | Batch 200/469 | Gen/Dis Loss: 0.8552/0.6576
# Epoch: 059/100 | Batch 300/469 | Gen/Dis Loss: 0.9164/0.6080
# Epoch: 059/100 | Batch 400/469 | Gen/Dis Loss: 0.8954/0.5999
# Time elapsed: 13.38 min
# Epoch: 060/100 | Batch 000/469 | Gen/Dis Loss: 1.0226/0.6367
# Epoch: 060/100 | Batch 100/469 | Gen/Dis Loss: 0.8566/0.6446
# Epoch: 060/100 | Batch 200/469 | Gen/Dis Loss: 0.8091/0.6176
# Epoch: 060/100 | Batch 300/469 | Gen/Dis Loss: 0.9045/0.6434
# Epoch: 060/100 | Batch 400/469 | Gen/Dis Loss: 0.9168/0.6424
# Time elapsed: 13.60 min
# Epoch: 061/100 | Batch 000/469 | Gen/Dis Loss: 0.9331/0.6237
# Epoch: 061/100 | Batch 100/469 | Gen/Dis Loss: 0.8530/0.6326
# Epoch: 061/100 | Batch 200/469 | Gen/Dis Loss: 0.7930/0.6358
# Epoch: 061/100 | Batch 300/469 | Gen/Dis Loss: 0.7566/0.6238
# Epoch: 061/100 | Batch 400/469 | Gen/Dis Loss: 1.0081/0.6341
# Time elapsed: 13.82 min
# Epoch: 062/100 | Batch 000/469 | Gen/Dis Loss: 0.9192/0.6744
# Epoch: 062/100 | Batch 100/469 | Gen/Dis Loss: 0.9625/0.6561
# Epoch: 062/100 | Batch 200/469 | Gen/Dis Loss: 0.7771/0.6531
# Epoch: 062/100 | Batch 300/469 | Gen/Dis Loss: 0.8719/0.5991
# Epoch: 062/100 | Batch 400/469 | Gen/Dis Loss: 0.9585/0.6169
# Time elapsed: 14.05 min
# Epoch: 063/100 | Batch 000/469 | Gen/Dis Loss: 0.8754/0.6083
# Epoch: 063/100 | Batch 100/469 | Gen/Dis Loss: 0.8404/0.6254
# Epoch: 063/100 | Batch 200/469 | Gen/Dis Loss: 0.7591/0.6467
# Epoch: 063/100 | Batch 300/469 | Gen/Dis Loss: 1.0175/0.6348
# Epoch: 063/100 | Batch 400/469 | Gen/Dis Loss: 0.7647/0.6352
# Time elapsed: 14.27 min
# Epoch: 064/100 | Batch 000/469 | Gen/Dis Loss: 0.7345/0.6207
# Epoch: 064/100 | Batch 100/469 | Gen/Dis Loss: 0.8773/0.5996
# Epoch: 064/100 | Batch 200/469 | Gen/Dis Loss: 0.9631/0.6175
# Epoch: 064/100 | Batch 300/469 | Gen/Dis Loss: 0.8566/0.6380
# Epoch: 064/100 | Batch 400/469 | Gen/Dis Loss: 0.9354/0.6402
# Time elapsed: 14.49 min
# Epoch: 065/100 | Batch 000/469 | Gen/Dis Loss: 0.8147/0.6295
# Epoch: 065/100 | Batch 100/469 | Gen/Dis Loss: 1.0463/0.5859
# Epoch: 065/100 | Batch 200/469 | Gen/Dis Loss: 0.8809/0.6703
# Epoch: 065/100 | Batch 300/469 | Gen/Dis Loss: 1.0083/0.6556
# Epoch: 065/100 | Batch 400/469 | Gen/Dis Loss: 0.7522/0.6356
# Time elapsed: 14.71 min
# Epoch: 066/100 | Batch 000/469 | Gen/Dis Loss: 0.9373/0.6074
# Epoch: 066/100 | Batch 100/469 | Gen/Dis Loss: 0.8385/0.6530
# Epoch: 066/100 | Batch 200/469 | Gen/Dis Loss: 1.1026/0.6213
# Epoch: 066/100 | Batch 300/469 | Gen/Dis Loss: 0.8690/0.5979
# Epoch: 066/100 | Batch 400/469 | Gen/Dis Loss: 0.8974/0.5991
# Time elapsed: 14.94 min
# Epoch: 067/100 | Batch 000/469 | Gen/Dis Loss: 0.8569/0.5939
# Epoch: 067/100 | Batch 100/469 | Gen/Dis Loss: 0.8288/0.6020
# Epoch: 067/100 | Batch 200/469 | Gen/Dis Loss: 0.9341/0.6213
# Epoch: 067/100 | Batch 300/469 | Gen/Dis Loss: 0.9221/0.6046
# Epoch: 067/100 | Batch 400/469 | Gen/Dis Loss: 0.7483/0.7112
# Time elapsed: 15.17 min
# Epoch: 068/100 | Batch 000/469 | Gen/Dis Loss: 0.8810/0.5907
# Epoch: 068/100 | Batch 100/469 | Gen/Dis Loss: 0.9842/0.5817
# Epoch: 068/100 | Batch 200/469 | Gen/Dis Loss: 0.8515/0.6309
# Epoch: 068/100 | Batch 300/469 | Gen/Dis Loss: 0.9030/0.6043
# Epoch: 068/100 | Batch 400/469 | Gen/Dis Loss: 0.8599/0.6503
# Time elapsed: 15.39 min
# Epoch: 069/100 | Batch 000/469 | Gen/Dis Loss: 0.8245/0.6320
# Epoch: 069/100 | Batch 100/469 | Gen/Dis Loss: 0.8392/0.6425
# Epoch: 069/100 | Batch 200/469 | Gen/Dis Loss: 0.8547/0.6061
# Epoch: 069/100 | Batch 300/469 | Gen/Dis Loss: 0.8781/0.6153
# Epoch: 069/100 | Batch 400/469 | Gen/Dis Loss: 0.9093/0.5909
# Time elapsed: 15.61 min
# Epoch: 070/100 | Batch 000/469 | Gen/Dis Loss: 0.8996/0.6491
# Epoch: 070/100 | Batch 100/469 | Gen/Dis Loss: 0.9789/0.6188
# Epoch: 070/100 | Batch 200/469 | Gen/Dis Loss: 0.7842/0.6616
# Epoch: 070/100 | Batch 300/469 | Gen/Dis Loss: 0.8308/0.6432
# Epoch: 070/100 | Batch 400/469 | Gen/Dis Loss: 0.8785/0.6008
# Time elapsed: 15.83 min
# Epoch: 071/100 | Batch 000/469 | Gen/Dis Loss: 0.9114/0.5944
# Epoch: 071/100 | Batch 100/469 | Gen/Dis Loss: 0.9226/0.6215
# Epoch: 071/100 | Batch 200/469 | Gen/Dis Loss: 0.8171/0.6583
# Epoch: 071/100 | Batch 300/469 | Gen/Dis Loss: 0.8021/0.6216
# Epoch: 071/100 | Batch 400/469 | Gen/Dis Loss: 1.0991/0.6411
# Time elapsed: 16.05 min
# Epoch: 072/100 | Batch 000/469 | Gen/Dis Loss: 0.8405/0.6372
# Epoch: 072/100 | Batch 100/469 | Gen/Dis Loss: 1.2204/0.6584
# Epoch: 072/100 | Batch 200/469 | Gen/Dis Loss: 0.8628/0.6064
# Epoch: 072/100 | Batch 300/469 | Gen/Dis Loss: 0.8974/0.6362
# Epoch: 072/100 | Batch 400/469 | Gen/Dis Loss: 0.8101/0.6532
# Time elapsed: 16.27 min
# Epoch: 073/100 | Batch 000/469 | Gen/Dis Loss: 0.8017/0.6440
# Epoch: 073/100 | Batch 100/469 | Gen/Dis Loss: 0.7838/0.5947
# Epoch: 073/100 | Batch 200/469 | Gen/Dis Loss: 0.7643/0.6272
# Epoch: 073/100 | Batch 300/469 | Gen/Dis Loss: 0.8007/0.6517
# Epoch: 073/100 | Batch 400/469 | Gen/Dis Loss: 0.7278/0.6335
# Time elapsed: 16.49 min
# Epoch: 074/100 | Batch 000/469 | Gen/Dis Loss: 0.8274/0.6469
# Epoch: 074/100 | Batch 100/469 | Gen/Dis Loss: 0.8411/0.6445
# Epoch: 074/100 | Batch 200/469 | Gen/Dis Loss: 0.8655/0.6011
# Epoch: 074/100 | Batch 300/469 | Gen/Dis Loss: 0.8294/0.6320
# Epoch: 074/100 | Batch 400/469 | Gen/Dis Loss: 0.8449/0.6195
# Time elapsed: 16.71 min
# Epoch: 075/100 | Batch 000/469 | Gen/Dis Loss: 0.7622/0.6799
# Epoch: 075/100 | Batch 100/469 | Gen/Dis Loss: 0.8666/0.6221
# Epoch: 075/100 | Batch 200/469 | Gen/Dis Loss: 0.8468/0.6343
# Epoch: 075/100 | Batch 300/469 | Gen/Dis Loss: 0.7799/0.6510
# Epoch: 075/100 | Batch 400/469 | Gen/Dis Loss: 0.8089/0.6607
# Time elapsed: 16.93 min
# Epoch: 076/100 | Batch 000/469 | Gen/Dis Loss: 1.1284/0.5795
# Epoch: 076/100 | Batch 100/469 | Gen/Dis Loss: 0.7906/0.6154
# Epoch: 076/100 | Batch 200/469 | Gen/Dis Loss: 0.8562/0.6453
# Epoch: 076/100 | Batch 300/469 | Gen/Dis Loss: 0.7680/0.6409
# Epoch: 076/100 | Batch 400/469 | Gen/Dis Loss: 0.8088/0.6197
# Time elapsed: 17.17 min
# Epoch: 077/100 | Batch 000/469 | Gen/Dis Loss: 0.7569/0.6519
# Epoch: 077/100 | Batch 100/469 | Gen/Dis Loss: 0.9081/0.6779
# Epoch: 077/100 | Batch 200/469 | Gen/Dis Loss: 0.9753/0.6546
# Epoch: 077/100 | Batch 300/469 | Gen/Dis Loss: 0.8142/0.6353
# Epoch: 077/100 | Batch 400/469 | Gen/Dis Loss: 0.8364/0.6325
# Time elapsed: 17.39 min
# Epoch: 078/100 | Batch 000/469 | Gen/Dis Loss: 0.8788/0.6249
# Epoch: 078/100 | Batch 100/469 | Gen/Dis Loss: 1.0244/0.6286
# Epoch: 078/100 | Batch 200/469 | Gen/Dis Loss: 0.8615/0.6190
# Epoch: 078/100 | Batch 300/469 | Gen/Dis Loss: 0.8475/0.6597
# Epoch: 078/100 | Batch 400/469 | Gen/Dis Loss: 0.8978/0.6240
# Time elapsed: 17.61 min
# Epoch: 079/100 | Batch 000/469 | Gen/Dis Loss: 0.8331/0.6413
# Epoch: 079/100 | Batch 100/469 | Gen/Dis Loss: 0.8559/0.6577
# Epoch: 079/100 | Batch 200/469 | Gen/Dis Loss: 1.0455/0.6323
# Epoch: 079/100 | Batch 300/469 | Gen/Dis Loss: 0.8582/0.6384
# Epoch: 079/100 | Batch 400/469 | Gen/Dis Loss: 0.8404/0.6427
# Time elapsed: 17.83 min
# Epoch: 080/100 | Batch 000/469 | Gen/Dis Loss: 0.8576/0.6435
# Epoch: 080/100 | Batch 100/469 | Gen/Dis Loss: 0.7966/0.6467
# Epoch: 080/100 | Batch 200/469 | Gen/Dis Loss: 0.9493/0.6524
# Epoch: 080/100 | Batch 300/469 | Gen/Dis Loss: 0.8754/0.6405
# Epoch: 080/100 | Batch 400/469 | Gen/Dis Loss: 0.8244/0.6358
# Time elapsed: 18.05 min
# Epoch: 081/100 | Batch 000/469 | Gen/Dis Loss: 0.8208/0.6466
# Epoch: 081/100 | Batch 100/469 | Gen/Dis Loss: 0.8109/0.6300
# Epoch: 081/100 | Batch 200/469 | Gen/Dis Loss: 0.7934/0.6344
# Epoch: 081/100 | Batch 300/469 | Gen/Dis Loss: 0.8775/0.6158
# Epoch: 081/100 | Batch 400/469 | Gen/Dis Loss: 1.0304/0.6245
# Time elapsed: 18.27 min
# Epoch: 082/100 | Batch 000/469 | Gen/Dis Loss: 0.8181/0.6194
# Epoch: 082/100 | Batch 100/469 | Gen/Dis Loss: 0.8408/0.6052
# Epoch: 082/100 | Batch 200/469 | Gen/Dis Loss: 0.7645/0.6530
# Epoch: 082/100 | Batch 300/469 | Gen/Dis Loss: 0.9452/0.6033
# Epoch: 082/100 | Batch 400/469 | Gen/Dis Loss: 0.8581/0.6179
# Time elapsed: 18.49 min
# Epoch: 083/100 | Batch 000/469 | Gen/Dis Loss: 0.8551/0.6133
# Epoch: 083/100 | Batch 100/469 | Gen/Dis Loss: 0.8922/0.6292
# Epoch: 083/100 | Batch 200/469 | Gen/Dis Loss: 0.7701/0.6465
# Epoch: 083/100 | Batch 300/469 | Gen/Dis Loss: 1.0076/0.6974
# Epoch: 083/100 | Batch 400/469 | Gen/Dis Loss: 0.8574/0.6519
# Time elapsed: 18.71 min
# Epoch: 084/100 | Batch 000/469 | Gen/Dis Loss: 0.8503/0.5944
# Epoch: 084/100 | Batch 100/469 | Gen/Dis Loss: 0.9956/0.6392
# Epoch: 084/100 | Batch 200/469 | Gen/Dis Loss: 0.9108/0.6505
# Epoch: 084/100 | Batch 300/469 | Gen/Dis Loss: 0.8364/0.6029
# Epoch: 084/100 | Batch 400/469 | Gen/Dis Loss: 0.7893/0.6344
# Time elapsed: 18.93 min
# Epoch: 085/100 | Batch 000/469 | Gen/Dis Loss: 0.9402/0.6193
# Epoch: 085/100 | Batch 100/469 | Gen/Dis Loss: 0.7989/0.6561
# Epoch: 085/100 | Batch 200/469 | Gen/Dis Loss: 0.8587/0.6037
# Epoch: 085/100 | Batch 300/469 | Gen/Dis Loss: 0.8429/0.6474
# Epoch: 085/100 | Batch 400/469 | Gen/Dis Loss: 0.8205/0.6395
# Time elapsed: 19.16 min
# Epoch: 086/100 | Batch 000/469 | Gen/Dis Loss: 0.8722/0.6353
# Epoch: 086/100 | Batch 100/469 | Gen/Dis Loss: 0.9122/0.6007
# Epoch: 086/100 | Batch 200/469 | Gen/Dis Loss: 1.0011/0.6220
# Epoch: 086/100 | Batch 300/469 | Gen/Dis Loss: 0.7788/0.6652
# Epoch: 086/100 | Batch 400/469 | Gen/Dis Loss: 0.9052/0.5950
# Time elapsed: 19.39 min
# Epoch: 087/100 | Batch 000/469 | Gen/Dis Loss: 0.9019/0.6323
# Epoch: 087/100 | Batch 100/469 | Gen/Dis Loss: 0.7495/0.6289
# Epoch: 087/100 | Batch 200/469 | Gen/Dis Loss: 0.8231/0.6777
# Epoch: 087/100 | Batch 300/469 | Gen/Dis Loss: 0.8451/0.6310
# Epoch: 087/100 | Batch 400/469 | Gen/Dis Loss: 0.8365/0.6346
# Time elapsed: 19.61 min
# Epoch: 088/100 | Batch 000/469 | Gen/Dis Loss: 0.7901/0.6624
# Epoch: 088/100 | Batch 100/469 | Gen/Dis Loss: 0.9427/0.6282
# Epoch: 088/100 | Batch 200/469 | Gen/Dis Loss: 0.7437/0.6774
# Epoch: 088/100 | Batch 300/469 | Gen/Dis Loss: 0.8286/0.6399
# Epoch: 088/100 | Batch 400/469 | Gen/Dis Loss: 0.8950/0.6124
# Time elapsed: 19.83 min
# Epoch: 089/100 | Batch 000/469 | Gen/Dis Loss: 0.8497/0.6292
# Epoch: 089/100 | Batch 100/469 | Gen/Dis Loss: 0.9852/0.6297
# Epoch: 089/100 | Batch 200/469 | Gen/Dis Loss: 0.9795/0.6301
# Epoch: 089/100 | Batch 300/469 | Gen/Dis Loss: 0.8382/0.6432
# Epoch: 089/100 | Batch 400/469 | Gen/Dis Loss: 0.8018/0.6649
# Time elapsed: 20.05 min
# Epoch: 090/100 | Batch 000/469 | Gen/Dis Loss: 0.8966/0.5814
# Epoch: 090/100 | Batch 100/469 | Gen/Dis Loss: 0.9367/0.6207
# Epoch: 090/100 | Batch 200/469 | Gen/Dis Loss: 0.9234/0.5984
# Epoch: 090/100 | Batch 300/469 | Gen/Dis Loss: 0.8383/0.6565
# Epoch: 090/100 | Batch 400/469 | Gen/Dis Loss: 0.8037/0.6556
# Time elapsed: 20.27 min
# Epoch: 091/100 | Batch 000/469 | Gen/Dis Loss: 0.8880/0.6530
# Epoch: 091/100 | Batch 100/469 | Gen/Dis Loss: 0.8516/0.6117
# Epoch: 091/100 | Batch 200/469 | Gen/Dis Loss: 0.8325/0.6299
# Epoch: 091/100 | Batch 300/469 | Gen/Dis Loss: 0.8625/0.6485
# Epoch: 091/100 | Batch 400/469 | Gen/Dis Loss: 0.9037/0.6264
# Time elapsed: 20.51 min
# Epoch: 092/100 | Batch 000/469 | Gen/Dis Loss: 0.7657/0.6749
# Epoch: 092/100 | Batch 100/469 | Gen/Dis Loss: 0.8454/0.6163
# Epoch: 092/100 | Batch 200/469 | Gen/Dis Loss: 0.9356/0.6090
# Epoch: 092/100 | Batch 300/469 | Gen/Dis Loss: 0.8627/0.6176
# Epoch: 092/100 | Batch 400/469 | Gen/Dis Loss: 0.7753/0.6491
# Time elapsed: 20.74 min
# Epoch: 093/100 | Batch 000/469 | Gen/Dis Loss: 0.8808/0.6279
# Epoch: 093/100 | Batch 100/469 | Gen/Dis Loss: 0.8104/0.6407
# Epoch: 093/100 | Batch 200/469 | Gen/Dis Loss: 0.9509/0.6285
# Epoch: 093/100 | Batch 300/469 | Gen/Dis Loss: 0.7773/0.6377
# Epoch: 093/100 | Batch 400/469 | Gen/Dis Loss: 1.0176/0.6295
# Time elapsed: 20.97 min
# Epoch: 094/100 | Batch 000/469 | Gen/Dis Loss: 0.7915/0.5945
# Epoch: 094/100 | Batch 100/469 | Gen/Dis Loss: 0.8070/0.6625
# Epoch: 094/100 | Batch 200/469 | Gen/Dis Loss: 0.8330/0.6424
# Epoch: 094/100 | Batch 300/469 | Gen/Dis Loss: 0.8036/0.6366
# Epoch: 094/100 | Batch 400/469 | Gen/Dis Loss: 0.8779/0.6321
# Time elapsed: 21.20 min
# Epoch: 095/100 | Batch 000/469 | Gen/Dis Loss: 0.9351/0.6386
# Epoch: 095/100 | Batch 100/469 | Gen/Dis Loss: 0.7371/0.6671
# Epoch: 095/100 | Batch 200/469 | Gen/Dis Loss: 0.9118/0.6152
# Epoch: 095/100 | Batch 300/469 | Gen/Dis Loss: 0.8646/0.6336
# Epoch: 095/100 | Batch 400/469 | Gen/Dis Loss: 0.8557/0.6228
# Time elapsed: 21.43 min
# Epoch: 096/100 | Batch 000/469 | Gen/Dis Loss: 0.8164/0.6650
# Epoch: 096/100 | Batch 100/469 | Gen/Dis Loss: 0.8334/0.6481
# Epoch: 096/100 | Batch 200/469 | Gen/Dis Loss: 0.8462/0.6680
# Epoch: 096/100 | Batch 300/469 | Gen/Dis Loss: 0.8710/0.6096
# Epoch: 096/100 | Batch 400/469 | Gen/Dis Loss: 0.8388/0.6212
# Time elapsed: 21.66 min
# Epoch: 097/100 | Batch 000/469 | Gen/Dis Loss: 0.8407/0.6495
# Epoch: 097/100 | Batch 100/469 | Gen/Dis Loss: 0.7944/0.6628
# Epoch: 097/100 | Batch 200/469 | Gen/Dis Loss: 0.9382/0.6428
# Epoch: 097/100 | Batch 300/469 | Gen/Dis Loss: 0.9146/0.6440
# Epoch: 097/100 | Batch 400/469 | Gen/Dis Loss: 0.8423/0.6390
# Time elapsed: 21.89 min
# Epoch: 098/100 | Batch 000/469 | Gen/Dis Loss: 0.7816/0.6483
# Epoch: 098/100 | Batch 100/469 | Gen/Dis Loss: 0.9256/0.6335
# Epoch: 098/100 | Batch 200/469 | Gen/Dis Loss: 1.0178/0.6364
# Epoch: 098/100 | Batch 300/469 | Gen/Dis Loss: 0.6892/0.6720
# Epoch: 098/100 | Batch 400/469 | Gen/Dis Loss: 0.8169/0.6459
# Time elapsed: 22.11 min
# Epoch: 099/100 | Batch 000/469 | Gen/Dis Loss: 0.9203/0.6391
# Epoch: 099/100 | Batch 100/469 | Gen/Dis Loss: 0.8782/0.6332
# Epoch: 099/100 | Batch 200/469 | Gen/Dis Loss: 0.9449/0.6475
# Epoch: 099/100 | Batch 300/469 | Gen/Dis Loss: 0.8205/0.6614
# Epoch: 099/100 | Batch 400/469 | Gen/Dis Loss: 0.9302/0.6405
# Time elapsed: 22.33 min
# Epoch: 100/100 | Batch 000/469 | Gen/Dis Loss: 0.8709/0.6705
# Epoch: 100/100 | Batch 100/469 | Gen/Dis Loss: 0.7723/0.6448
# Epoch: 100/100 | Batch 200/469 | Gen/Dis Loss: 0.8932/0.5814
# Epoch: 100/100 | Batch 300/469 | Gen/Dis Loss: 0.9400/0.6472
# Epoch: 100/100 | Batch 400/469 | Gen/Dis Loss: 0.8426/0.6575
# Time elapsed: 22.55 min
# Total Training Time: 22.55 min

# %% [markdown]
# ## Evaluation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(gener_costs)), gener_costs, label='generator loss')
plt.plot(range(len(discr_costs)), discr_costs, label='discriminator loss')
plt.legend()
plt.show()

# %%
##########################
### VISUALIZATION
##########################


model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))


for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')
